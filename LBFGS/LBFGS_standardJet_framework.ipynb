# %% [markdown]
# # Verification: LBFGS in vcl.StandardJet framework vs general LBFGS framework

# %% [markdown]
# ## LBFGS in vcl.StandardJet framework

# %%
import vcl
import npvc
import vcalg
import optimizationAlg_2

sp = npvc.Space(4)

x = vcl.Vector(sp)
x.data[0]=-1.2
x.data[1]=1.0
x.data[2]=-1.2
x.data[3]=1.0

b = vcl.Vector(sp)
b.data[0]=0
b.data[1]=-1
b.data[2]=0
b.data[3]=-1

F = npvc.DoubleRosie(sp)
lsq = vcl.LeastSquares(F,b)

print('\n****************** ')
print('\n LBFGS test')
print('\n****************** ')


m = 5
alpha = 1.0
c = 0.0001
iterMax = 100
verbose = 1
beta = 0.5
eps = 0.00000000000001
Kmax = 1200
tol = 0.00001
plot_on = 0 #  plot for the solution
gamma = 1
x = optimizationAlg_2.lbfgs(vcl.StandardJet, x, m, sp, sp, iterMax, 
                        alpha, beta, c, verbose, eps, gamma, tol,
                        Kmax, plot_on, jetargs=dict(fcn=lsq))

print('\nSolution')
x.myNameIs()
# Out:
# ******************
#
#  LBFGS test
#
# ******************
#
# Iteration 1 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  14.9072 dfp = -13601.205376
#
# During Line Search:
#
# fxvalue is 14.9072
# i=0    alpha=1.0   f(x) =  14.9072   f(x)-f(xn)=-6405496796.832956
# ||p||=116.62420578936432     ||df||=116.62420578936432    dfp=-13601.205376
# c*alpha*dfp=-1.3601205376
#
#
# fxvalue is 14.9072
# i=1    alpha=0.5   f(x) =  14.9072   f(x)-f(xn)=-379307001.6565687
# ||p||=116.62420578936432     ||df||=116.62420578936432    dfp=-13601.205376
# c*alpha*dfp=-0.6800602688
#
#
# fxvalue is 14.9072
# i=2    alpha=0.25   f(x) =  14.9072   f(x)-f(xn)=-21194413.74786695
# ||p||=116.62420578936432     ||df||=116.62420578936432    dfp=-13601.205376
# c*alpha*dfp=-0.3400301344
#
#
# fxvalue is 14.9072
# i=3    alpha=0.125   f(x) =  14.9072   f(x)-f(xn)=-1039382.4309733049
# ||p||=116.62420578936432     ||df||=116.62420578936432    dfp=-13601.205376
# c*alpha*dfp=-0.1700150672
#
#
# fxvalue is 14.9072
# i=4    alpha=0.0625   f(x) =  14.9072   f(x)-f(xn)=-36215.36835520786
# ||p||=116.62420578936432     ||df||=116.62420578936432    dfp=-13601.205376
# c*alpha*dfp=-0.0850075336
#
#
# fxvalue is 14.9072
# i=5    alpha=0.03125   f(x) =  14.9072   f(x)-f(xn)=-258.8708280409666
# ||p||=116.62420578936432     ||df||=116.62420578936432    dfp=-13601.205376
# c*alpha*dfp=-0.0425037668
#
#
# fxvalue is 14.9072
# i=6    alpha=0.015625   f(x) =  14.9072   f(x)-f(xn)=-93.03909843097915
# ||p||=116.62420578936432     ||df||=116.62420578936432    dfp=-13601.205376
# c*alpha*dfp=-0.0212518834
#
#
# fxvalue is 14.9072
# i=7    alpha=0.0078125   f(x) =  14.9072   f(x)-f(xn)=-62.41437727070338
# ||p||=116.62420578936432     ||df||=116.62420578936432    dfp=-13601.205376
# c*alpha*dfp=-0.0106259417
#
#
# fxvalue is 14.9072
# i=8    alpha=0.00390625   f(x) =  14.9072   f(x)-f(xn)=-5.29063584494358
# ||p||=116.62420578936432     ||df||=116.62420578936432    dfp=-13601.205376
# c*alpha*dfp=-0.00531297085
#
#
# i=9    alpha=0.001953125   f(x)=14.9072    f(x)-f(xn)=9.633508886487022
# ||p||=116.62420578936432     ||df||=116.62420578936432    dfp=-13601.205376
# c*alpha*dfp=-0.002656485425
#
# k = 1 alpha = 0.001953125 f(xn) = 5.273691113512978 ||df|| = 22.825833382423582
# The total run time for this line search is: 0.0037479400634765625 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 2 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  5.273691113512978 dfp = -0.8570240739528455
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=5.273691113512978    f(x)-f(xn)=0.537695429136579
# ||p||=0.037546233672798725     ||df||=22.825833382423582    dfp=-0.8570240739528455
# c*alpha*dfp=-8.570240739528455e-05
#
# k = 2 alpha = 1.0 f(xn) = 4.735995684376399 ||df|| = 7.277726503358392
# The total run time for this line search is: 0.0005259513854980469 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 3 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  4.735995684376399 dfp = -0.10762684416999976
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=4.735995684376399    f(x)-f(xn)=0.0877007673352157
# ||p||=0.014788525526527287     ||df||=7.277726503358392    dfp=-0.10762684416999976
# c*alpha*dfp=-1.0762684416999977e-05
#
# k = 3 alpha = 1.0 f(xn) = 4.648294917041183 ||df|| = 5.680192581174437
# The total run time for this line search is: 0.0009500980377197266 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 4 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  4.648294917041183 dfp = -0.06928569148183991
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=4.648294917041183    f(x)-f(xn)=0.06716564836618932
# ||p||=0.012197771552934637     ||df||=5.680192581174437    dfp=-0.06928569148183991
# c*alpha*dfp=-6.928569148183991e-06
#
# k = 4 alpha = 1.0 f(xn) = 4.581129268674994 ||df|| = 5.339210662671698
# The total run time for this line search is: 0.0007779598236083984 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 5 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  4.581129268674994 dfp = -0.6832732479681037
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=4.581129268674994    f(x)-f(xn)=0.4786408544062164
# ||p||=0.1279727081654799     ||df||=5.339210662671698    dfp=-0.6832732479681037
# c*alpha*dfp=-6.832732479681038e-05
#
# k = 5 alpha = 1.0 f(xn) = 4.102488414268778 ||df|| = 2.404277557590971
# The total run time for this line search is: 0.0005567073822021484 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 6 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  4.102488414268778 dfp = -0.27441173154984067
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=4.102488414268778    f(x)-f(xn)=0.19105847188163327
# ||p||=0.11596025034900952     ||df||=2.404277557590971    dfp=-0.27441173154984067
# c*alpha*dfp=-2.7441173154984068e-05
#
# k = 6 alpha = 1.0 f(xn) = 3.9114299423871444 ||df|| = 1.3348401191678845
# The total run time for this line search is: 0.0004956722259521484 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 7 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  3.9114299423871444 dfp = -0.19681552806493544
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=3.9114299423871444    f(x)-f(xn)=0.1693940937705083
# ||p||=0.15608708825369486     ||df||=1.3348401191678845    dfp=-0.19681552806493544
# c*alpha*dfp=-1.9681552806493544e-05
#
# k = 7 alpha = 1.0 f(xn) = 3.742035848616636 ||df|| = 1.7746507995518759
# The total run time for this line search is: 0.0005691051483154297 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 8 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  3.742035848616636 dfp = -0.784934988725102
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=3.742035848616636    f(x)-f(xn)=0.6755785887653136
# ||p||=0.7207811366093357     ||df||=1.7746507995518759    dfp=-0.784934988725102
# c*alpha*dfp=-7.84934988725102e-05
#
# k = 8 alpha = 1.0 f(xn) = 3.0664572598513224 ||df|| = 11.331427837336745
# The total run time for this line search is: 0.0006680488586425781 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 9 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  3.0664572598513224 dfp = -2.1314304782189684
#
# During Line Search:
#
# fxvalue is 3.0664572598513224
# i=0    alpha=1.0   f(x) =  3.0664572598513224   f(x)-f(xn)=-32.33650291366213
# ||p||=2.2661083411454928     ||df||=11.331427837336745    dfp=-2.1314304782189684
# c*alpha*dfp=-0.00021314304782189684
#
#
# fxvalue is 3.0664572598513224
# i=1    alpha=0.5   f(x) =  3.0664572598513224   f(x)-f(xn)=-2.316812728541402
# ||p||=2.2661083411454928     ||df||=11.331427837336745    dfp=-2.1314304782189684
# c*alpha*dfp=-0.00010657152391094842
#
#
# i=2    alpha=0.25   f(x)=3.0664572598513224    f(x)-f(xn)=0.10031704627199822
# ||p||=2.2661083411454928     ||df||=11.331427837336745    dfp=-2.1314304782189684
# c*alpha*dfp=-5.328576195547421e-05
#
# k = 9 alpha = 0.25 f(xn) = 2.9661402135793242 ||df|| = 21.733702018780924
# The total run time for this line search is: 0.0010640621185302734 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 10 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  2.9661402135793242 dfp = -1.0413671771047848
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=2.9661402135793242    f(x)-f(xn)=0.6992103175958708
# ||p||=0.10171766804177831     ||df||=21.733702018780924    dfp=-1.0413671771047848
# c*alpha*dfp=-0.00010413671771047849
#
# k = 10 alpha = 1.0 f(xn) = 2.2669298959834534 ||df|| = 9.548358743146563
# The total run time for this line search is: 0.0014178752899169922 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 11 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  2.2669298959834534 dfp = -0.9705169770243063
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=2.2669298959834534    f(x)-f(xn)=0.7682929524011737
# ||p||=0.3870962093603379     ||df||=9.548358743146563    dfp=-0.9705169770243063
# c*alpha*dfp=-9.705169770243064e-05
#
# k = 11 alpha = 1.0 f(xn) = 1.4986369435822797 ||df|| = 6.6219813885487815
# The total run time for this line search is: 0.0006930828094482422 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 12 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  1.4986369435822797 dfp = -0.9464015300774156
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=1.4986369435822797    f(x)-f(xn)=0.1649980274702254
# ||p||=0.5321799425648844     ||df||=6.6219813885487815    dfp=-0.9464015300774156
# c*alpha*dfp=-9.464015300774156e-05
#
# k = 12 alpha = 1.0 f(xn) = 1.3336389161120543 ||df|| = 9.43933604278556
# The total run time for this line search is: 0.0008351802825927734 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 13 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  1.3336389161120543 dfp = -1.4326850779838585
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=1.3336389161120543    f(x)-f(xn)=0.08739270404091037
# ||p||=0.22910867933590023     ||df||=9.43933604278556    dfp=-1.4326850779838585
# c*alpha*dfp=-0.00014326850779838586
#
# k = 13 alpha = 1.0 f(xn) = 1.246246212071144 ||df|| = 7.492480744939131
# The total run time for this line search is: 0.0012402534484863281 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 14 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  1.246246212071144 dfp = -0.5546426491183633
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=1.246246212071144    f(x)-f(xn)=0.288601848274723
# ||p||=0.08358607051401251     ||df||=7.492480744939131    dfp=-0.5546426491183633
# c*alpha*dfp=-5.5464264911836326e-05
#
# k = 14 alpha = 1.0 f(xn) = 0.9576443637964209 ||df|| = 1.4126772405161958
# The total run time for this line search is: 0.0004980564117431641 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 15 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  0.9576443637964209 dfp = -0.026826468075517806
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=0.9576443637964209    f(x)-f(xn)=0.02124443996515213
# ||p||=0.045103608552752625     ||df||=1.4126772405161958    dfp=-0.026826468075517806
# c*alpha*dfp=-2.6826468075517806e-06
#
# k = 15 alpha = 1.0 f(xn) = 0.9363999238312688 ||df|| = 1.703039654089509
# The total run time for this line search is: 0.0005831718444824219 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 16 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  0.9363999238312688 dfp = -0.10858761909025916
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=0.9363999238312688    f(x)-f(xn)=0.08186963823957305
# ||p||=0.11402455413321688     ||df||=1.703039654089509    dfp=-0.10858761909025916
# c*alpha*dfp=-1.0858761909025917e-05
#
# k = 16 alpha = 1.0 f(xn) = 0.8545302855916957 ||df|| = 2.7836112411569243
# The total run time for this line search is: 0.00038886070251464844 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 17 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  0.8545302855916957 dfp = -0.1694730032005884
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=0.8545302855916957    f(x)-f(xn)=0.08453809542025092
# ||p||=0.1592235012052744     ||df||=2.7836112411569243    dfp=-0.1694730032005884
# c*alpha*dfp=-1.694730032005884e-05
#
# k = 17 alpha = 1.0 f(xn) = 0.7699921901714448 ||df|| = 4.981337599553329
# The total run time for this line search is: 0.0007350444793701172 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 18 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  0.7699921901714448 dfp = -0.21091124655276067
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=0.7699921901714448    f(x)-f(xn)=0.1555294959633967
# ||p||=0.0860633089367583     ||df||=4.981337599553329    dfp=-0.21091124655276067
# c*alpha*dfp=-2.1091124655276066e-05
#
# k = 18 alpha = 1.0 f(xn) = 0.6144626942080481 ||df|| = 2.4976870754593605
# The total run time for this line search is: 0.0006730556488037109 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 19 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  0.6144626942080481 dfp = -0.19822101836146738
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=0.6144626942080481    f(x)-f(xn)=0.13189519906334618
# ||p||=0.18703012520858064     ||df||=2.4976870754593605    dfp=-0.19822101836146738
# c*alpha*dfp=-1.9822101836146738e-05
#
# k = 19 alpha = 1.0 f(xn) = 0.48256749514470193 ||df|| = 2.6574761229719224
# The total run time for this line search is: 0.0004172325134277344 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 20 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  0.48256749514470193 dfp = -0.5020135639726566
#
# During Line Search:
#
# fxvalue is 0.48256749514470193
# i=0    alpha=1.0   f(x) =  0.48256749514470193   f(x)-f(xn)=-0.7741350620537015
# ||p||=0.499587478614825     ||df||=2.6574761229719224    dfp=-0.5020135639726566
# c*alpha*dfp=-5.0201356397265665e-05
#
#
# i=1    alpha=0.5   f(x)=0.48256749514470193    f(x)-f(xn)=0.03547409045612521
# ||p||=0.499587478614825     ||df||=2.6574761229719224    dfp=-0.5020135639726566
# c*alpha*dfp=-2.5100678198632833e-05
#
# k = 20 alpha = 0.5 f(xn) = 0.4470934046885767 ||df|| = 4.865295522458309
# The total run time for this line search is: 0.0006668567657470703 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 21 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  0.4470934046885767 dfp = -0.38193745051713324
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=0.4470934046885767    f(x)-f(xn)=0.08329263116317476
# ||p||=0.10465638444090654     ||df||=4.865295522458309    dfp=-0.38193745051713324
# c*alpha*dfp=-3.819374505171332e-05
#
# k = 21 alpha = 1.0 f(xn) = 0.36380077352540197 ||df|| = 4.157981463695624
# The total run time for this line search is: 0.0006551742553710938 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 22 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  0.36380077352540197 dfp = -0.27790729242100815
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=0.36380077352540197    f(x)-f(xn)=0.10014638510203056
# ||p||=0.21074375409984886     ||df||=4.157981463695624    dfp=-0.27790729242100815
# c*alpha*dfp=-2.7790729242100814e-05
#
# k = 22 alpha = 1.0 f(xn) = 0.2636543884233714 ||df|| = 1.9017239308428582
# The total run time for this line search is: 0.00041604042053222656 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 23 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  0.2636543884233714 dfp = -0.08633339506643033
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=0.2636543884233714    f(x)-f(xn)=0.0585619859331441
# ||p||=0.07861434660604391     ||df||=1.9017239308428582    dfp=-0.08633339506643033
# c*alpha*dfp=-8.633339506643033e-06
#
# k = 23 alpha = 1.0 f(xn) = 0.2050924024902273 ||df|| = 1.5646171564845928
# The total run time for this line search is: 0.0006279945373535156 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 24 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  0.2050924024902273 dfp = -0.062287358642944844
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=0.2050924024902273    f(x)-f(xn)=0.041642512675737126
# ||p||=0.14917544216638182     ||df||=1.5646171564845928    dfp=-0.062287358642944844
# c*alpha*dfp=-6.228735864294484e-06
#
# k = 24 alpha = 1.0 f(xn) = 0.16344988981449018 ||df|| = 2.5064150761728623
# The total run time for this line search is: 0.0004928112030029297 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 25 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  0.16344988981449018 dfp = -0.10458216280245437
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=0.16344988981449018    f(x)-f(xn)=0.03151279963932194
# ||p||=0.1885762885865709     ||df||=2.5064150761728623    dfp=-0.10458216280245437
# c*alpha*dfp=-1.0458216280245438e-05
#
# k = 25 alpha = 1.0 f(xn) = 0.13193709017516825 ||df|| = 2.2863316688165245
# The total run time for this line search is: 0.0012972354888916016 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 26 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  0.13193709017516825 dfp = -0.09547900560680815
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=0.13193709017516825    f(x)-f(xn)=0.04039795548079256
# ||p||=0.247709989631996     ||df||=2.2863316688165245    dfp=-0.09547900560680815
# c*alpha*dfp=-9.547900560680815e-06
#
# k = 26 alpha = 1.0 f(xn) = 0.09153913469437569 ||df|| = 3.4577820469590472
# The total run time for this line search is: 0.0004322528839111328 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 27 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  0.09153913469437569 dfp = -0.07158876149319784
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=0.09153913469437569    f(x)-f(xn)=0.02499344436866474
# ||p||=0.06705784181878864     ||df||=3.4577820469590472    dfp=-0.07158876149319784
# c*alpha*dfp=-7.1588761493197845e-06
#
# k = 27 alpha = 1.0 f(xn) = 0.06654569032571095 ||df|| = 0.43562553960245315
# The total run time for this line search is: 0.0007789134979248047 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 28 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  0.06654569032571095 dfp = -0.01703703419758519
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=0.06654569032571095    f(x)-f(xn)=0.014157929529207053
# ||p||=0.10430154981531334     ||df||=0.43562553960245315    dfp=-0.01703703419758519
# c*alpha*dfp=-1.7037034197585192e-06
#
# k = 28 alpha = 1.0 f(xn) = 0.052387760796503896 ||df|| = 0.8053036589589706
# The total run time for this line search is: 0.0005450248718261719 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 29 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  0.052387760796503896 dfp = -0.028735788842181295
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=0.052387760796503896    f(x)-f(xn)=0.010140399548894494
# ||p||=0.2510997224670241     ||df||=0.8053036589589706    dfp=-0.028735788842181295
# c*alpha*dfp=-2.8735788842181296e-06
#
# k = 29 alpha = 1.0 f(xn) = 0.0422473612476094 ||df|| = 2.541610342427201
# The total run time for this line search is: 0.0003819465637207031 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 30 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  0.0422473612476094 dfp = -0.016955159050925917
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=0.0422473612476094    f(x)-f(xn)=0.008003275524152857
# ||p||=0.031224665012147892     ||df||=2.541610342427201    dfp=-0.016955159050925917
# c*alpha*dfp=-1.6955159050925918e-06
#
# k = 30 alpha = 1.0 f(xn) = 0.034244085723456545 ||df|| = 0.300594401940309
# The total run time for this line search is: 0.0005021095275878906 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 31 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  0.034244085723456545 dfp = -0.005073645637092684
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=0.034244085723456545    f(x)-f(xn)=0.003847371310606803
# ||p||=0.07254886112733432     ||df||=0.300594401940309    dfp=-0.005073645637092684
# c*alpha*dfp=-5.073645637092684e-07
#
# k = 31 alpha = 1.0 f(xn) = 0.030396714412849742 ||df|| = 0.20186316647095562
# The total run time for this line search is: 0.00034999847412109375 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 32 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  0.030396714412849742 dfp = -0.02161505265544634
#
# During Line Search:
#
# fxvalue is 0.030396714412849742
# i=0    alpha=1.0   f(x) =  0.030396714412849742   f(x)-f(xn)=-0.10756616012610037
# ||p||=0.5513262468930729     ||df||=0.20186316647095562    dfp=-0.02161505265544634
# c*alpha*dfp=-2.161505265544634e-06
#
#
# fxvalue is 0.030396714412849742
# i=1    alpha=0.5   f(x) =  0.030396714412849742   f(x)-f(xn)=-0.009454339809751248
# ||p||=0.5513262468930729     ||df||=0.20186316647095562    dfp=-0.02161505265544634
# c*alpha*dfp=-1.080752632772317e-06
#
#
# i=2    alpha=0.25   f(x)=0.030396714412849742    f(x)-f(xn)=0.0011511444044410638
# ||p||=0.5513262468930729     ||df||=0.20186316647095562    dfp=-0.02161505265544634
# c*alpha*dfp=-5.403763163861585e-07
#
# k = 32 alpha = 0.25 f(xn) = 0.02924557000840868 ||df|| = 0.5971539487243791
# The total run time for this line search is: 0.0013151168823242188 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 33 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  0.02924557000840868 dfp = -0.004741937618531452
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=0.02924557000840868    f(x)-f(xn)=0.0028027111192044443
# ||p||=0.013480243241583957     ||df||=0.5971539487243791    dfp=-0.004741937618531452
# c*alpha*dfp=-4.7419376185314516e-07
#
# k = 33 alpha = 1.0 f(xn) = 0.026442858889204234 ||df|| = 0.3032269774022798
# The total run time for this line search is: 0.0005300045013427734 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 34 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  0.026442858889204234 dfp = -0.0010958018818096628
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=0.026442858889204234    f(x)-f(xn)=0.0008783654107048199
# ||p||=0.01945271660289894     ||df||=0.3032269774022798    dfp=-0.0010958018818096628
# c*alpha*dfp=-1.0958018818096629e-07
#
# k = 34 alpha = 1.0 f(xn) = 0.025564493478499414 ||df|| = 0.10641024488087798
# The total run time for this line search is: 0.0004532337188720703 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 35 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  0.025564493478499414 dfp = -0.0020454446149214727
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=0.025564493478499414    f(x)-f(xn)=0.0015343765279646586
# ||p||=0.05551571970818524     ||df||=0.10641024488087798    dfp=-0.0020454446149214727
# c*alpha*dfp=-2.0454446149214728e-07
#
# k = 35 alpha = 1.0 f(xn) = 0.024030116950534756 ||df|| = 0.20670477223438555
# The total run time for this line search is: 0.0004961490631103516 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 36 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  0.024030116950534756 dfp = -0.0031641035777745536
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=0.024030116950534756    f(x)-f(xn)=0.0024098232939814626
# ||p||=0.06167322882835737     ||df||=0.20670477223438555    dfp=-0.0031641035777745536
# c*alpha*dfp=-3.1641035777745537e-07
#
# k = 36 alpha = 1.0 f(xn) = 0.021620293656553293 ||df|| = 0.2465083381380604
# The total run time for this line search is: 0.0006589889526367188 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 37 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  0.021620293656553293 dfp = -0.011343125196615414
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=0.021620293656553293    f(x)-f(xn)=0.005755922584339816
# ||p||=0.19308543718582055     ||df||=0.2465083381380604    dfp=-0.011343125196615414
# c*alpha*dfp=-1.1343125196615415e-06
#
# k = 37 alpha = 1.0 f(xn) = 0.015864371072213477 ||df|| = 0.6891082682546459
# The total run time for this line search is: 0.000377655029296875 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 38 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  0.015864371072213477 dfp = -0.007237162264062362
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=0.015864371072213477    f(x)-f(xn)=0.0020431651031940917
# ||p||=0.0539032900382023     ||df||=0.6891082682546459    dfp=-0.007237162264062362
# c*alpha*dfp=-7.237162264062363e-07
#
# k = 38 alpha = 1.0 f(xn) = 0.013821205969019385 ||df|| = 1.405267378320686
# The total run time for this line search is: 0.0005731582641601562 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 39 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  0.013821205969019385 dfp = -0.005602916600243715
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=0.013821205969019385    f(x)-f(xn)=0.004331866764498463
# ||p||=0.08344703100066962     ||df||=1.405267378320686    dfp=-0.005602916600243715
# c*alpha*dfp=-5.602916600243716e-07
#
# k = 39 alpha = 1.0 f(xn) = 0.009489339204520922 ||df|| = 0.2810992626474793
# The total run time for this line search is: 0.0003719329833984375 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 40 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  0.009489339204520922 dfp = -0.005666527245430924
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=0.009489339204520922    f(x)-f(xn)=0.002592686133446125
# ||p||=0.13443410323693444     ||df||=0.2810992626474793    dfp=-0.005666527245430924
# c*alpha*dfp=-5.666527245430925e-07
#
# k = 40 alpha = 1.0 f(xn) = 0.006896653071074797 ||df|| = 1.0470978969466305
# The total run time for this line search is: 0.0019011497497558594 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 41 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  0.006896653071074797 dfp = -0.006023787534303472
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=0.006896653071074797    f(x)-f(xn)=0.004214729370550248
# ||p||=0.09926447008460015     ||df||=1.0470978969466305    dfp=-0.006023787534303472
# c*alpha*dfp=-6.023787534303472e-07
#
# k = 41 alpha = 1.0 f(xn) = 0.002681923700524549 ||df|| = 0.24242363370711364
# The total run time for this line search is: 0.00045013427734375 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 42 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  0.002681923700524549 dfp = -0.0029761633674175152
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=0.002681923700524549    f(x)-f(xn)=0.0018354478866406696
# ||p||=0.10518111790220713     ||df||=0.24242363370711364    dfp=-0.0029761633674175152
# c*alpha*dfp=-2.9761633674175155e-07
#
# k = 42 alpha = 1.0 f(xn) = 0.0008464758138838795 ||df|| = 0.1735930183637686
# The total run time for this line search is: 0.0005679130554199219 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 43 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  0.0008464758138838795 dfp = -0.005936083442822783
#
# During Line Search:
#
# fxvalue is 0.0008464758138838795
# i=0    alpha=1.0   f(x) =  0.0008464758138838795   f(x)-f(xn)=-0.006078018599889828
# ||p||=0.03608741945562591     ||df||=0.1735930183637686    dfp=-0.005936083442822783
# c*alpha*dfp=-5.936083442822783e-07
#
#
# fxvalue is 0.0008464758138838795
# i=1    alpha=0.5   f(x) =  0.0008464758138838795   f(x)-f(xn)=-7.984414367823937e-05
# ||p||=0.03608741945562591     ||df||=0.1735930183637686    dfp=-0.005936083442822783
# c*alpha*dfp=-2.9680417214113915e-07
#
#
# i=2    alpha=0.25   f(x)=0.0008464758138838795    f(x)-f(xn)=0.0007164720361018663
# ||p||=0.03608741945562591     ||df||=0.1735930183637686    dfp=-0.005936083442822783
# c*alpha*dfp=-1.4840208607056957e-07
#
# k = 43 alpha = 0.25 f(xn) = 0.0001300037777820132 ||df|| = 0.06081683992153282
# The total run time for this line search is: 0.0009300708770751953 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 44 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  0.0001300037777820132 dfp = -0.0003317385851217056
#
# During Line Search:
#
# fxvalue is 0.0001300037777820132
# i=0    alpha=1.0   f(x) =  0.0001300037777820132   f(x)-f(xn)=-7.080975046535232e-06
# ||p||=0.044363766497535956     ||df||=0.06081683992153282    dfp=-0.0003317385851217056
# c*alpha*dfp=-3.317385851217056e-08
#
#
# i=1    alpha=0.5   f(x)=0.0001300037777820132    f(x)-f(xn)=8.635906119773716e-05
# ||p||=0.044363766497535956     ||df||=0.06081683992153282    dfp=-0.0003317385851217056
# c*alpha*dfp=-1.658692925608528e-08
#
# k = 44 alpha = 0.5 f(xn) = 4.364471658427604e-05 ||df|| = 0.12327002764052043
# The total run time for this line search is: 0.0007779598236083984 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 45 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  4.364471658427604e-05 dfp = -8.534679214989974e-05
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=4.364471658427604e-05    f(x)-f(xn)=4.205405539931316e-05
# ||p||=0.018160465602174353     ||df||=0.12327002764052043    dfp=-8.534679214989974e-05
# c*alpha*dfp=-8.534679214989975e-09
#
# k = 45 alpha = 1.0 f(xn) = 1.5906611849628737e-06 ||df|| = 0.017664718229857625
# The total run time for this line search is: 0.0003731250762939453 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 46 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  1.5906611849628737e-06 dfp = -1.9411790095248874e-06
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=1.5906611849628737e-06    f(x)-f(xn)=1.3264503671034394e-06
# ||p||=0.002082958529263826     ||df||=0.017664718229857625    dfp=-1.9411790095248874e-06
# c*alpha*dfp=-1.9411790095248876e-10
#
# k = 46 alpha = 1.0 f(xn) = 2.6421081785943426e-07 ||df|| = 0.008962987308917546
# The total run time for this line search is: 0.0006580352783203125 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 47 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  2.6421081785943426e-07 dfp = -5.543449684769486e-07
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=2.6421081785943426e-07    f(x)-f(xn)=2.5933176100618754e-07
# ||p||=0.001382065162001439     ||df||=0.008962987308917546    dfp=-5.543449684769486e-07
# c*alpha*dfp=-5.543449684769486e-11
#
# k = 47 alpha = 1.0 f(xn) = 4.879056853246718e-09 ||df|| = 0.001146594821790424
# The total run time for this line search is: 0.0004889965057373047 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 48 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  4.879056853246718e-09 dfp = -9.485771525862448e-09
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=4.879056853246718e-09    f(x)-f(xn)=4.8712977597762765e-09
# ||p||=3.170906375662748e-05     ||df||=0.001146594821790424    dfp=-9.485771525862448e-09
# c*alpha*dfp=-9.48577152586245e-13
#
# k = 48 alpha = 1.0 f(xn) = 7.759093470441674e-12 ||df|| = 2.9896498508311182e-05
# The total run time for this line search is: 0.0008068084716796875 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 49 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  7.759093470441674e-12 dfp = -1.3847623603882157e-11
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=7.759093470441674e-12    f(x)-f(xn)=7.539600927324275e-12
# ||p||=1.9369247333738345e-06     ||df||=2.9896498508311182e-05    dfp=-1.3847623603882157e-11
# c*alpha*dfp=-1.3847623603882156e-15
#
# k = 49 alpha = 1.0 f(xn) = 2.1949254311740023e-13 ||df|| = 1.1698455216577693e-05
# The total run time for this line search is: 0.0009860992431640625 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 50 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  2.1949254311740023e-13 dfp = -4.262292833557075e-13
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=2.1949254311740023e-13    f(x)-f(xn)=1.843850740958944e-13
# ||p||=1.0682941994857698e-06     ||df||=1.1698455216577693e-05    dfp=-4.262292833557075e-13
# c*alpha*dfp=-4.262292833557075e-17
#
# k = 50 alpha = 1.0 f(xn) = 3.510746902150582e-14 ||df|| = 3.6648231017873212e-06
# The total run time for this line search is: 0.0006418228149414062 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
# total function evals = 17
# total gradient evals = 50
# total backtracking steps = 17
#
# Solution
# Vector in space:
# npvc.Space of dimension 4
# Data object:
# [[0.99999984]
#  [0.99999967]
#  [0.99999987]
#  [0.99999977]]

# %% [markdown]
# ## General LBFGS framework

# %%
import vcl
import npvc
import vcalg
import linalg
import numpy as np
import func
import lsalg

# total gradient evaluation
gtot = 0
#total backtracking steps
ktot = 0
#total function evaluation
jtot = 0

dom = npvc.Space(4)
rng = npvc.Space(4)



s_set = []
y_set = []
s = vcl.Vector(dom)
y = vcl.Vector(dom)
df = vcl.Vector(dom)
df_old = vcl.Vector(dom)
q = vcl.Vector(dom)
p = vcl.Vector(dom)
x_old = vcl.Vector(dom)
r = vcl.Vector(dom)

# the number of vector pair {s,y} we want to keep
m = 5
k = 0

f = func.DoubleRosie(dom,rng)
x = vcl.Vector(dom)
b = vcl.Vector(rng)
b.data[0]=0
b.data[1]=-1
b.data[2]=0
b.data[3]=-1
x.data[0]=-1.2
x.data[1]=1.0
x.data[2]=-1.2
x.data[3]=1.0
J = vcl.LeastSquares(f,b)
df=J.gradient(x)
df_old.copy(df)


m = 5
alpha = 1.0
c = 0.0001
iterMax = 100
verbose = 1
beta = 0.5
eps = 0.00000000000001
Kmax = 1200
tol = 0.00001
plot_on = 0 #  plot for the solution
gamma = 1


while df.norm() > tol and k <= Kmax:
    p = lsalg.descent_direction_1(df, k, m, s_set, y_set, gamma)
    x_old.copy(x)
    [i, x, jtot, ktot] = lsalg.bt_lineSearch_1(J, x, df, p, k, iterMax, alpha, beta, c, verbose, jtot, ktot)
    
    if plot_on > 0:
        print(" ")
        print("The updated slowness: ")
        print(" ")
        linalg.simplot(mest.data, addcb=True, minval=2.5, maxval=4.5)
        
    if i == iterMax:
        print("The line search failed.")
        break
    f_obj = J(x)
    df_old.copy(df)
    df = J.gradient(x)
    gtot += 1
    # s_k = x_{k+1} - x_k
    s.copy(x)
    s.linComb(-1,x_old,1)
    # y_k = df_{k+1} - df_k
    y.copy(df)
    y.linComb(-1,df_old,1)

    if k < m:
        s_set.append(s.dup())
        y_set.append(y.dup())

    
    if k >= m and s.dot(y) > eps*s.norm()*y.norm():
        s_set.pop(0)
        s_set.append(s.dup())
        y_set.pop(0)
        y_set.append(y.dup())     
    gamma = s_set[-1].dot(y_set[-1])/y_set[-1].dot(y_set[-1])
    k += 1
    if k >= Kmax:
        print("The BFGFS algorithm reached the maximum number of iterations.")
        break


print(f"total function evals = {jtot}")
print(f"total gradient evals = {gtot}")
print(f"total backtracking steps = {ktot}")
x.myNameIs()
# Out:
#
# Iteration 1 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  + 14.9072 dfp = -13601.205376
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=14.9072    f(x)-f(xn)=-6405496796.832956
# ||p||=116.62420578936432     ||df||=116.62420578936432    dfp=-13601.205376
# c*alpha*dfp=-1.3601205376
#
#
# i=1    alpha=0.5   f(x)=14.9072    f(x)-f(xn)=-379307001.6565687
# ||p||=116.62420578936432     ||df||=116.62420578936432    dfp=-13601.205376
# c*alpha*dfp=-0.6800602688
#
#
# i=2    alpha=0.25   f(x)=14.9072    f(x)-f(xn)=-21194413.74786695
# ||p||=116.62420578936432     ||df||=116.62420578936432    dfp=-13601.205376
# c*alpha*dfp=-0.3400301344
#
#
# i=3    alpha=0.125   f(x)=14.9072    f(x)-f(xn)=-1039382.4309733049
# ||p||=116.62420578936432     ||df||=116.62420578936432    dfp=-13601.205376
# c*alpha*dfp=-0.1700150672
#
#
# i=4    alpha=0.0625   f(x)=14.9072    f(x)-f(xn)=-36215.36835520786
# ||p||=116.62420578936432     ||df||=116.62420578936432    dfp=-13601.205376
# c*alpha*dfp=-0.0850075336
#
#
# i=5    alpha=0.03125   f(x)=14.9072    f(x)-f(xn)=-258.8708280409666
# ||p||=116.62420578936432     ||df||=116.62420578936432    dfp=-13601.205376
# c*alpha*dfp=-0.0425037668
#
#
# i=6    alpha=0.015625   f(x)=14.9072    f(x)-f(xn)=-93.03909843097915
# ||p||=116.62420578936432     ||df||=116.62420578936432    dfp=-13601.205376
# c*alpha*dfp=-0.0212518834
#
#
# i=7    alpha=0.0078125   f(x)=14.9072    f(x)-f(xn)=-62.41437727070338
# ||p||=116.62420578936432     ||df||=116.62420578936432    dfp=-13601.205376
# c*alpha*dfp=-0.0106259417
#
#
# i=8    alpha=0.00390625   f(x)=14.9072    f(x)-f(xn)=-5.29063584494358
# ||p||=116.62420578936432     ||df||=116.62420578936432    dfp=-13601.205376
# c*alpha*dfp=-0.00531297085
#
#
# i=9    alpha=0.001953125   f(x)=14.9072    f(x)-f(xn)=9.633508886487022
# ||p||=116.62420578936432     ||df||=116.62420578936432    dfp=-13601.205376
# c*alpha*dfp=-0.002656485425
#
# k = 1 alpha = 0.001953125 f(xn) = 5.273691113512978 ||df|| = 22.825833382423582
# The total run time for this line search is: 0.06557917594909668 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 2 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  + 5.273691113512978 dfp = -0.8570240739528455
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=5.273691113512978    f(x)-f(xn)=0.537695429136579
# ||p||=0.037546233672798725     ||df||=22.825833382423582    dfp=-0.8570240739528455
# c*alpha*dfp=-8.570240739528455e-05
#
# k = 2 alpha = 1.0 f(xn) = 4.735995684376399 ||df|| = 7.277726503358392
# The total run time for this line search is: 0.0005810260772705078 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 3 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  + 4.735995684376399 dfp = -0.10762684416999976
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=4.735995684376399    f(x)-f(xn)=0.0877007673352157
# ||p||=0.014788525526527287     ||df||=7.277726503358392    dfp=-0.10762684416999976
# c*alpha*dfp=-1.0762684416999977e-05
#
# k = 3 alpha = 1.0 f(xn) = 4.648294917041183 ||df|| = 5.680192581174437
# The total run time for this line search is: 0.0005047321319580078 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 4 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  + 4.648294917041183 dfp = -0.06928569148183991
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=4.648294917041183    f(x)-f(xn)=0.06716564836618932
# ||p||=0.012197771552934637     ||df||=5.680192581174437    dfp=-0.06928569148183991
# c*alpha*dfp=-6.928569148183991e-06
#
# k = 4 alpha = 1.0 f(xn) = 4.581129268674994 ||df|| = 5.339210662671698
# The total run time for this line search is: 0.00040912628173828125 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 5 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  + 4.581129268674994 dfp = -0.6832732479681037
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=4.581129268674994    f(x)-f(xn)=0.4786408544062164
# ||p||=0.1279727081654799     ||df||=5.339210662671698    dfp=-0.6832732479681037
# c*alpha*dfp=-6.832732479681038e-05
#
# k = 5 alpha = 1.0 f(xn) = 4.102488414268778 ||df|| = 2.404277557590971
# The total run time for this line search is: 0.0011479854583740234 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 6 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  + 4.102488414268778 dfp = -0.27441173154984067
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=4.102488414268778    f(x)-f(xn)=0.19105847188163327
# ||p||=0.11596025034900952     ||df||=2.404277557590971    dfp=-0.27441173154984067
# c*alpha*dfp=-2.7441173154984068e-05
#
# k = 6 alpha = 1.0 f(xn) = 3.9114299423871444 ||df|| = 1.3348401191678845
# The total run time for this line search is: 0.0018711090087890625 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 7 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  + 3.9114299423871444 dfp = -0.19681552806493544
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=3.9114299423871444    f(x)-f(xn)=0.1693940937705083
# ||p||=0.15608708825369486     ||df||=1.3348401191678845    dfp=-0.19681552806493544
# c*alpha*dfp=-1.9681552806493544e-05
#
# k = 7 alpha = 1.0 f(xn) = 3.742035848616636 ||df|| = 1.7746507995518759
# The total run time for this line search is: 0.0009658336639404297 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 8 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  + 3.742035848616636 dfp = -0.784934988725102
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=3.742035848616636    f(x)-f(xn)=0.6755785887653136
# ||p||=0.7207811366093357     ||df||=1.7746507995518759    dfp=-0.784934988725102
# c*alpha*dfp=-7.84934988725102e-05
#
# k = 8 alpha = 1.0 f(xn) = 3.0664572598513224 ||df|| = 11.331427837336745
# The total run time for this line search is: 0.0008232593536376953 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 9 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  + 3.0664572598513224 dfp = -2.1314304782189684
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=3.0664572598513224    f(x)-f(xn)=-32.33650291366213
# ||p||=2.2661083411454928     ||df||=11.331427837336745    dfp=-2.1314304782189684
# c*alpha*dfp=-0.00021314304782189684
#
#
# i=1    alpha=0.5   f(x)=3.0664572598513224    f(x)-f(xn)=-2.316812728541402
# ||p||=2.2661083411454928     ||df||=11.331427837336745    dfp=-2.1314304782189684
# c*alpha*dfp=-0.00010657152391094842
#
#
# i=2    alpha=0.25   f(x)=3.0664572598513224    f(x)-f(xn)=0.10031704627199822
# ||p||=2.2661083411454928     ||df||=11.331427837336745    dfp=-2.1314304782189684
# c*alpha*dfp=-5.328576195547421e-05
#
# k = 9 alpha = 0.25 f(xn) = 2.9661402135793242 ||df|| = 21.733702018780924
# The total run time for this line search is: 0.0008971691131591797 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 10 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  + 2.9661402135793242 dfp = -1.0413671771047848
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=2.9661402135793242    f(x)-f(xn)=0.6992103175958708
# ||p||=0.10171766804177831     ||df||=21.733702018780924    dfp=-1.0413671771047848
# c*alpha*dfp=-0.00010413671771047849
#
# k = 10 alpha = 1.0 f(xn) = 2.2669298959834534 ||df|| = 9.548358743146563
# The total run time for this line search is: 0.000415802001953125 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 11 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  + 2.2669298959834534 dfp = -0.9705169770243063
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=2.2669298959834534    f(x)-f(xn)=0.7682929524011737
# ||p||=0.3870962093603379     ||df||=9.548358743146563    dfp=-0.9705169770243063
# c*alpha*dfp=-9.705169770243064e-05
#
# k = 11 alpha = 1.0 f(xn) = 1.4986369435822797 ||df|| = 6.6219813885487815
# The total run time for this line search is: 0.0005843639373779297 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 12 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  + 1.4986369435822797 dfp = -0.9464015300774156
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=1.4986369435822797    f(x)-f(xn)=0.1649980274702254
# ||p||=0.5321799425648844     ||df||=6.6219813885487815    dfp=-0.9464015300774156
# c*alpha*dfp=-9.464015300774156e-05
#
# k = 12 alpha = 1.0 f(xn) = 1.3336389161120543 ||df|| = 9.43933604278556
# The total run time for this line search is: 0.0007193088531494141 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 13 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  + 1.3336389161120543 dfp = -1.4326850779838585
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=1.3336389161120543    f(x)-f(xn)=0.08739270404091037
# ||p||=0.22910867933590023     ||df||=9.43933604278556    dfp=-1.4326850779838585
# c*alpha*dfp=-0.00014326850779838586
#
# k = 13 alpha = 1.0 f(xn) = 1.246246212071144 ||df|| = 7.492480744939131
# The total run time for this line search is: 0.000370025634765625 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 14 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  + 1.246246212071144 dfp = -0.5546426491183633
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=1.246246212071144    f(x)-f(xn)=0.288601848274723
# ||p||=0.08358607051401251     ||df||=7.492480744939131    dfp=-0.5546426491183633
# c*alpha*dfp=-5.5464264911836326e-05
#
# k = 14 alpha = 1.0 f(xn) = 0.9576443637964209 ||df|| = 1.4126772405161958
# The total run time for this line search is: 0.0005879402160644531 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 15 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  + 0.9576443637964209 dfp = -0.026826468075517806
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=0.9576443637964209    f(x)-f(xn)=0.02124443996515213
# ||p||=0.045103608552752625     ||df||=1.4126772405161958    dfp=-0.026826468075517806
# c*alpha*dfp=-2.6826468075517806e-06
#
# k = 15 alpha = 1.0 f(xn) = 0.9363999238312688 ||df|| = 1.703039654089509
# The total run time for this line search is: 0.000392913818359375 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 16 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  + 0.9363999238312688 dfp = -0.10858761909025916
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=0.9363999238312688    f(x)-f(xn)=0.08186963823957305
# ||p||=0.11402455413321688     ||df||=1.703039654089509    dfp=-0.10858761909025916
# c*alpha*dfp=-1.0858761909025917e-05
#
# k = 16 alpha = 1.0 f(xn) = 0.8545302855916957 ||df|| = 2.7836112411569243
# The total run time for this line search is: 0.0008559226989746094 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 17 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  + 0.8545302855916957 dfp = -0.1694730032005884
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=0.8545302855916957    f(x)-f(xn)=0.08453809542025092
# ||p||=0.1592235012052744     ||df||=2.7836112411569243    dfp=-0.1694730032005884
# c*alpha*dfp=-1.694730032005884e-05
#
# k = 17 alpha = 1.0 f(xn) = 0.7699921901714448 ||df|| = 4.981337599553329
# The total run time for this line search is: 0.0006420612335205078 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 18 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  + 0.7699921901714448 dfp = -0.21091124655276067
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=0.7699921901714448    f(x)-f(xn)=0.1555294959633967
# ||p||=0.0860633089367583     ||df||=4.981337599553329    dfp=-0.21091124655276067
# c*alpha*dfp=-2.1091124655276066e-05
#
# k = 18 alpha = 1.0 f(xn) = 0.6144626942080481 ||df|| = 2.4976870754593605
# The total run time for this line search is: 0.0005409717559814453 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 19 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  + 0.6144626942080481 dfp = -0.19822101836146738
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=0.6144626942080481    f(x)-f(xn)=0.13189519906334618
# ||p||=0.18703012520858064     ||df||=2.4976870754593605    dfp=-0.19822101836146738
# c*alpha*dfp=-1.9822101836146738e-05
#
# k = 19 alpha = 1.0 f(xn) = 0.48256749514470193 ||df|| = 2.6574761229719224
# The total run time for this line search is: 0.0004978179931640625 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 20 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  + 0.48256749514470193 dfp = -0.5020135639726566
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=0.48256749514470193    f(x)-f(xn)=-0.7741350620537015
# ||p||=0.499587478614825     ||df||=2.6574761229719224    dfp=-0.5020135639726566
# c*alpha*dfp=-5.0201356397265665e-05
#
#
# i=1    alpha=0.5   f(x)=0.48256749514470193    f(x)-f(xn)=0.03547409045612521
# ||p||=0.499587478614825     ||df||=2.6574761229719224    dfp=-0.5020135639726566
# c*alpha*dfp=-2.5100678198632833e-05
#
# k = 20 alpha = 0.5 f(xn) = 0.4470934046885767 ||df|| = 4.865295522458309
# The total run time for this line search is: 0.0009038448333740234 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 21 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  + 0.4470934046885767 dfp = -0.38193745051713324
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=0.4470934046885767    f(x)-f(xn)=0.08329263116317476
# ||p||=0.10465638444090654     ||df||=4.865295522458309    dfp=-0.38193745051713324
# c*alpha*dfp=-3.819374505171332e-05
#
# k = 21 alpha = 1.0 f(xn) = 0.36380077352540197 ||df|| = 4.157981463695624
# The total run time for this line search is: 0.00041675567626953125 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 22 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  + 0.36380077352540197 dfp = -0.27790729242100815
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=0.36380077352540197    f(x)-f(xn)=0.10014638510203056
# ||p||=0.21074375409984886     ||df||=4.157981463695624    dfp=-0.27790729242100815
# c*alpha*dfp=-2.7790729242100814e-05
#
# k = 22 alpha = 1.0 f(xn) = 0.2636543884233714 ||df|| = 1.9017239308428582
# The total run time for this line search is: 0.0007779598236083984 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 23 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  + 0.2636543884233714 dfp = -0.08633339506643033
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=0.2636543884233714    f(x)-f(xn)=0.0585619859331441
# ||p||=0.07861434660604391     ||df||=1.9017239308428582    dfp=-0.08633339506643033
# c*alpha*dfp=-8.633339506643033e-06
#
# k = 23 alpha = 1.0 f(xn) = 0.2050924024902273 ||df|| = 1.5646171564845928
# The total run time for this line search is: 0.0008299350738525391 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 24 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  + 0.2050924024902273 dfp = -0.062287358642944844
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=0.2050924024902273    f(x)-f(xn)=0.041642512675737126
# ||p||=0.14917544216638182     ||df||=1.5646171564845928    dfp=-0.062287358642944844
# c*alpha*dfp=-6.228735864294484e-06
#
# k = 24 alpha = 1.0 f(xn) = 0.16344988981449018 ||df|| = 2.5064150761728623
# The total run time for this line search is: 0.0003781318664550781 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 25 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  + 0.16344988981449018 dfp = -0.10458216280245437
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=0.16344988981449018    f(x)-f(xn)=0.03151279963932194
# ||p||=0.1885762885865709     ||df||=2.5064150761728623    dfp=-0.10458216280245437
# c*alpha*dfp=-1.0458216280245438e-05
#
# k = 25 alpha = 1.0 f(xn) = 0.13193709017516825 ||df|| = 2.2863316688165245
# The total run time for this line search is: 0.0005040168762207031 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 26 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  + 0.13193709017516825 dfp = -0.09547900560680815
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=0.13193709017516825    f(x)-f(xn)=0.04039795548079256
# ||p||=0.247709989631996     ||df||=2.2863316688165245    dfp=-0.09547900560680815
# c*alpha*dfp=-9.547900560680815e-06
#
# k = 26 alpha = 1.0 f(xn) = 0.09153913469437569 ||df|| = 3.4577820469590472
# The total run time for this line search is: 0.00040221214294433594 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 27 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  + 0.09153913469437569 dfp = -0.07158876149319784
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=0.09153913469437569    f(x)-f(xn)=0.02499344436866474
# ||p||=0.06705784181878864     ||df||=3.4577820469590472    dfp=-0.07158876149319784
# c*alpha*dfp=-7.1588761493197845e-06
#
# k = 27 alpha = 1.0 f(xn) = 0.06654569032571095 ||df|| = 0.43562553960245315
# The total run time for this line search is: 0.0005712509155273438 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 28 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  + 0.06654569032571095 dfp = -0.01703703419758519
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=0.06654569032571095    f(x)-f(xn)=0.014157929529207053
# ||p||=0.10430154981531334     ||df||=0.43562553960245315    dfp=-0.01703703419758519
# c*alpha*dfp=-1.7037034197585192e-06
#
# k = 28 alpha = 1.0 f(xn) = 0.052387760796503896 ||df|| = 0.8053036589589706
# The total run time for this line search is: 0.06205582618713379 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 29 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  + 0.052387760796503896 dfp = -0.028735788842181295
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=0.052387760796503896    f(x)-f(xn)=0.010140399548894494
# ||p||=0.2510997224670241     ||df||=0.8053036589589706    dfp=-0.028735788842181295
# c*alpha*dfp=-2.8735788842181296e-06
#
# k = 29 alpha = 1.0 f(xn) = 0.0422473612476094 ||df|| = 2.541610342427201
# The total run time for this line search is: 0.0008552074432373047 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 30 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  + 0.0422473612476094 dfp = -0.016955159050925917
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=0.0422473612476094    f(x)-f(xn)=0.008003275524152857
# ||p||=0.031224665012147892     ||df||=2.541610342427201    dfp=-0.016955159050925917
# c*alpha*dfp=-1.6955159050925918e-06
#
# k = 30 alpha = 1.0 f(xn) = 0.034244085723456545 ||df|| = 0.300594401940309
# The total run time for this line search is: 0.0008168220520019531 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 31 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  + 0.034244085723456545 dfp = -0.005073645637092684
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=0.034244085723456545    f(x)-f(xn)=0.003847371310606803
# ||p||=0.07254886112733432     ||df||=0.300594401940309    dfp=-0.005073645637092684
# c*alpha*dfp=-5.073645637092684e-07
#
# k = 31 alpha = 1.0 f(xn) = 0.030396714412849742 ||df|| = 0.20186316647095562
# The total run time for this line search is: 0.0006320476531982422 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 32 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  + 0.030396714412849742 dfp = -0.02161505265544634
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=0.030396714412849742    f(x)-f(xn)=-0.10756616012610037
# ||p||=0.5513262468930729     ||df||=0.20186316647095562    dfp=-0.02161505265544634
# c*alpha*dfp=-2.161505265544634e-06
#
#
# i=1    alpha=0.5   f(x)=0.030396714412849742    f(x)-f(xn)=-0.009454339809751248
# ||p||=0.5513262468930729     ||df||=0.20186316647095562    dfp=-0.02161505265544634
# c*alpha*dfp=-1.080752632772317e-06
#
#
# i=2    alpha=0.25   f(x)=0.030396714412849742    f(x)-f(xn)=0.0011511444044410638
# ||p||=0.5513262468930729     ||df||=0.20186316647095562    dfp=-0.02161505265544634
# c*alpha*dfp=-5.403763163861585e-07
#
# k = 32 alpha = 0.25 f(xn) = 0.02924557000840868 ||df|| = 0.5971539487243791
# The total run time for this line search is: 0.000701904296875 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 33 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  + 0.02924557000840868 dfp = -0.004741937618531452
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=0.02924557000840868    f(x)-f(xn)=0.0028027111192044443
# ||p||=0.013480243241583957     ||df||=0.5971539487243791    dfp=-0.004741937618531452
# c*alpha*dfp=-4.7419376185314516e-07
#
# k = 33 alpha = 1.0 f(xn) = 0.026442858889204234 ||df|| = 0.3032269774022798
# The total run time for this line search is: 0.0005908012390136719 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 34 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  + 0.026442858889204234 dfp = -0.0010958018818096628
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=0.026442858889204234    f(x)-f(xn)=0.0008783654107048199
# ||p||=0.01945271660289894     ||df||=0.3032269774022798    dfp=-0.0010958018818096628
# c*alpha*dfp=-1.0958018818096629e-07
#
# k = 34 alpha = 1.0 f(xn) = 0.025564493478499414 ||df|| = 0.10641024488087798
# The total run time for this line search is: 0.0003829002380371094 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 35 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  + 0.025564493478499414 dfp = -0.0020454446149214727
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=0.025564493478499414    f(x)-f(xn)=0.0015343765279646586
# ||p||=0.05551571970818524     ||df||=0.10641024488087798    dfp=-0.0020454446149214727
# c*alpha*dfp=-2.0454446149214728e-07
#
# k = 35 alpha = 1.0 f(xn) = 0.024030116950534756 ||df|| = 0.20670477223438555
# The total run time for this line search is: 0.0006067752838134766 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 36 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  + 0.024030116950534756 dfp = -0.0031641035777745536
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=0.024030116950534756    f(x)-f(xn)=0.0024098232939814626
# ||p||=0.06167322882835737     ||df||=0.20670477223438555    dfp=-0.0031641035777745536
# c*alpha*dfp=-3.1641035777745537e-07
#
# k = 36 alpha = 1.0 f(xn) = 0.021620293656553293 ||df|| = 0.2465083381380604
# The total run time for this line search is: 0.0005500316619873047 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 37 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  + 0.021620293656553293 dfp = -0.011343125196615414
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=0.021620293656553293    f(x)-f(xn)=0.005755922584339816
# ||p||=0.19308543718582055     ||df||=0.2465083381380604    dfp=-0.011343125196615414
# c*alpha*dfp=-1.1343125196615415e-06
#
# k = 37 alpha = 1.0 f(xn) = 0.015864371072213477 ||df|| = 0.6891082682546459
# The total run time for this line search is: 0.0008158683776855469 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 38 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  + 0.015864371072213477 dfp = -0.007237162264062362
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=0.015864371072213477    f(x)-f(xn)=0.0020431651031940917
# ||p||=0.0539032900382023     ||df||=0.6891082682546459    dfp=-0.007237162264062362
# c*alpha*dfp=-7.237162264062363e-07
#
# k = 38 alpha = 1.0 f(xn) = 0.013821205969019385 ||df|| = 1.405267378320686
# The total run time for this line search is: 0.0009148120880126953 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 39 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  + 0.013821205969019385 dfp = -0.005602916600243715
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=0.013821205969019385    f(x)-f(xn)=0.004331866764498463
# ||p||=0.08344703100066962     ||df||=1.405267378320686    dfp=-0.005602916600243715
# c*alpha*dfp=-5.602916600243716e-07
#
# k = 39 alpha = 1.0 f(xn) = 0.009489339204520922 ||df|| = 0.2810992626474793
# The total run time for this line search is: 0.0008115768432617188 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 40 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  + 0.009489339204520922 dfp = -0.005666527245430924
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=0.009489339204520922    f(x)-f(xn)=0.002592686133446125
# ||p||=0.13443410323693444     ||df||=0.2810992626474793    dfp=-0.005666527245430924
# c*alpha*dfp=-5.666527245430925e-07
#
# k = 40 alpha = 1.0 f(xn) = 0.006896653071074797 ||df|| = 1.0470978969466305
# The total run time for this line search is: 0.0004200935363769531 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 41 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  + 0.006896653071074797 dfp = -0.006023787534303472
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=0.006896653071074797    f(x)-f(xn)=0.004214729370550248
# ||p||=0.09926447008460015     ||df||=1.0470978969466305    dfp=-0.006023787534303472
# c*alpha*dfp=-6.023787534303472e-07
#
# k = 41 alpha = 1.0 f(xn) = 0.002681923700524549 ||df|| = 0.24242363370711364
# The total run time for this line search is: 0.0007061958312988281 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 42 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  + 0.002681923700524549 dfp = -0.0029761633674175152
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=0.002681923700524549    f(x)-f(xn)=0.0018354478866406696
# ||p||=0.10518111790220713     ||df||=0.24242363370711364    dfp=-0.0029761633674175152
# c*alpha*dfp=-2.9761633674175155e-07
#
# k = 42 alpha = 1.0 f(xn) = 0.0008464758138838795 ||df|| = 0.1735930183637686
# The total run time for this line search is: 0.0007190704345703125 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 43 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  + 0.0008464758138838795 dfp = -0.005936083442822783
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=0.0008464758138838795    f(x)-f(xn)=-0.006078018599889828
# ||p||=0.03608741945562591     ||df||=0.1735930183637686    dfp=-0.005936083442822783
# c*alpha*dfp=-5.936083442822783e-07
#
#
# i=1    alpha=0.5   f(x)=0.0008464758138838795    f(x)-f(xn)=-7.984414367823937e-05
# ||p||=0.03608741945562591     ||df||=0.1735930183637686    dfp=-0.005936083442822783
# c*alpha*dfp=-2.9680417214113915e-07
#
#
# i=2    alpha=0.25   f(x)=0.0008464758138838795    f(x)-f(xn)=0.0007164720361018663
# ||p||=0.03608741945562591     ||df||=0.1735930183637686    dfp=-0.005936083442822783
# c*alpha*dfp=-1.4840208607056957e-07
#
# k = 43 alpha = 0.25 f(xn) = 0.0001300037777820132 ||df|| = 0.06081683992153282
# The total run time for this line search is: 0.0007071495056152344 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 44 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  + 0.0001300037777820132 dfp = -0.0003317385851217056
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=0.0001300037777820132    f(x)-f(xn)=-7.080975046535232e-06
# ||p||=0.044363766497535956     ||df||=0.06081683992153282    dfp=-0.0003317385851217056
# c*alpha*dfp=-3.317385851217056e-08
#
#
# i=1    alpha=0.5   f(x)=0.0001300037777820132    f(x)-f(xn)=8.635906119773716e-05
# ||p||=0.044363766497535956     ||df||=0.06081683992153282    dfp=-0.0003317385851217056
# c*alpha*dfp=-1.658692925608528e-08
#
# k = 44 alpha = 0.5 f(xn) = 4.364471658427604e-05 ||df|| = 0.12327002764052043
# The total run time for this line search is: 0.000659942626953125 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 45 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  + 4.364471658427604e-05 dfp = -8.534679214989974e-05
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=4.364471658427604e-05    f(x)-f(xn)=4.205405539931316e-05
# ||p||=0.018160465602174353     ||df||=0.12327002764052043    dfp=-8.534679214989974e-05
# c*alpha*dfp=-8.534679214989975e-09
#
# k = 45 alpha = 1.0 f(xn) = 1.5906611849628737e-06 ||df|| = 0.017664718229857625
# The total run time for this line search is: 0.0003910064697265625 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 46 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  + 1.5906611849628737e-06 dfp = -1.9411790095248874e-06
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=1.5906611849628737e-06    f(x)-f(xn)=1.3264503671034394e-06
# ||p||=0.002082958529263826     ||df||=0.017664718229857625    dfp=-1.9411790095248874e-06
# c*alpha*dfp=-1.9411790095248876e-10
#
# k = 46 alpha = 1.0 f(xn) = 2.6421081785943426e-07 ||df|| = 0.008962987308917546
# The total run time for this line search is: 0.00042176246643066406 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 47 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  + 2.6421081785943426e-07 dfp = -5.543449684769486e-07
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=2.6421081785943426e-07    f(x)-f(xn)=2.5933176100618754e-07
# ||p||=0.001382065162001439     ||df||=0.008962987308917546    dfp=-5.543449684769486e-07
# c*alpha*dfp=-5.543449684769486e-11
#
# k = 47 alpha = 1.0 f(xn) = 4.879056853246718e-09 ||df|| = 0.001146594821790424
# The total run time for this line search is: 0.000579833984375 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 48 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  + 4.879056853246718e-09 dfp = -9.485771525862448e-09
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=4.879056853246718e-09    f(x)-f(xn)=4.8712977597762765e-09
# ||p||=3.170906375662748e-05     ||df||=0.001146594821790424    dfp=-9.485771525862448e-09
# c*alpha*dfp=-9.48577152586245e-13
#
# k = 48 alpha = 1.0 f(xn) = 7.759093470441674e-12 ||df|| = 2.9896498508311182e-05
# The total run time for this line search is: 0.00055694580078125 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 49 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  + 7.759093470441674e-12 dfp = -1.3847623603882157e-11
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=7.759093470441674e-12    f(x)-f(xn)=7.539600927324275e-12
# ||p||=1.9369247333738345e-06     ||df||=2.9896498508311182e-05    dfp=-1.3847623603882157e-11
# c*alpha*dfp=-1.3847623603882156e-15
#
# k = 49 alpha = 1.0 f(xn) = 2.1949254311740023e-13 ||df|| = 1.1698455216577693e-05
# The total run time for this line search is: 0.0006258487701416016 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# Iteration 50 of LBFGS:
# i is the iteration counter for line search.
#
# Before Line Search:
# i = 0 alpha = 0 f(x) =  + 2.1949254311740023e-13 dfp = -4.262292833557075e-13
#
# During Line Search:
#
# i=0    alpha=1.0   f(x)=2.1949254311740023e-13    f(x)-f(xn)=1.843850740958944e-13
# ||p||=1.0682941994857698e-06     ||df||=1.1698455216577693e-05    dfp=-4.262292833557075e-13
# c*alpha*dfp=-4.262292833557075e-17
#
# k = 50 alpha = 1.0 f(xn) = 3.510746902150582e-14 ||df|| = 3.6648231017873212e-06
# The total run time for this line search is: 0.0008690357208251953 sec.
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
# total function evals = 17
# total gradient evals = 50
# total backtracking steps = 17
# Vector in space:
# npvc.Space of dimension 4
# Data object:
# [[0.99999984]
#  [0.99999967]
#  [0.99999987]
#  [0.99999977]]
